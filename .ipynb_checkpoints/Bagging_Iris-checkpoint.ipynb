# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, f1_score
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.drop('Id', axis = 1, inplace = True)

# %%
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
df =df[df['Species'] != 0][['SepalWidthCm','PetalLengthCm','Species']]
df.head()
# Out:
#     SepalWidthCm  PetalLengthCm  Species
# 50           3.2            4.7        1
# 51           3.2            4.5        1
# 52           3.1            4.9        1
# 53           2.3            4.0        1
# 54           2.8            4.6        1

# %%
plt.scatter(df['SepalWidthCm'], df['PetalLengthCm'], c = df['Species'], cmap = 'winter')

# %%
#taking only 10 rows for training
df = df.sample(100)
df_train = df.iloc[:60, :].sample(10)
df_val = df.iloc[60:80,:].sample(5)
df_test = df.iloc[80:,:].sample(5)

# %%
df_train
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 72            2.5            4.9        1
# 100           3.3            6.0        2
# 77            3.0            5.0        1
# 52            3.1            4.9        1
# 141           3.1            5.1        2
# 146           2.5            5.0        2
# 89            2.5            4.0        1
# 61            3.0            4.2        1
# 74            2.9            4.3        1
# 81            2.4            3.7        1

# %%
X_test = df_val.iloc[:, 0:2].values
y_test = df_val.iloc[:, -1].values
y_test
# Out:
# array([2, 1, 1, 2, 2])

# %% [markdown]
# # Bagging

# %%
#Data for tree 1
df_bag = df_train.sample(8, replace=True)
X = df_bag.iloc[:, 0:2].values
y = df_bag.iloc[:, -1].values
df_bag
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 100           3.3            6.0        2
# 141           3.1            5.1        2
# 74            2.9            4.3        1
# 81            2.4            3.7        1
# 146           2.5            5.0        2
# 89            2.5            4.0        1
# 141           3.1            5.1        2
# 146           2.5            5.0        2

# %%
dt_bag1 = DecisionTreeClassifier()

# %%
def evaluate(clf, X,y):
    clf.fit(X,y)
    plot_tree(clf)
    plt.show()
    plot_decision_regions(X, y, clf = clf, legend = 2)
    y_pred = clf.predict(X_test)
    print(accuracy_score(y_test, y_pred))

# %%
evaluate(dt_bag1, X, y)
# Out:
# 0.8

# %%
#Data for tree 2
df_bag = df_train.sample(8, replace=True)
X = df_bag.iloc[:, 0:2].values
y = df_bag.iloc[:, -1].values
df_bag
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 74            2.9            4.3        1
# 72            2.5            4.9        1
# 52            3.1            4.9        1
# 77            3.0            5.0        1
# 141           3.1            5.1        2
# 146           2.5            5.0        2
# 61            3.0            4.2        1
# 141           3.1            5.1        2

# %%
dt_bag2 = DecisionTreeClassifier()

# %%
evaluate(dt_bag2, X, y)
# Out:
# 0.6

# %%
#Data for tree 3
df_bag = df_train.sample(8, replace=True)
X = df_bag.iloc[:, 0:2].values
y = df_bag.iloc[:, -1].values
df_bag
# Out:
#     SepalWidthCm  PetalLengthCm  Species
# 77           3.0            5.0        1
# 89           2.5            4.0        1
# 61           3.0            4.2        1
# 89           2.5            4.0        1
# 52           3.1            4.9        1
# 52           3.1            4.9        1
# 81           2.4            3.7        1
# 61           3.0            4.2        1

# %%
dt_bag3 = DecisionTreeClassifier()

# %%
evaluate(dt_bag3, X, y)
# Out:
# 0.4

# %% [markdown]
# # Predict

# %%
df_test
# Out:
#      SepalWidthCm  PetalLengthCm  Species
# 70            3.2            4.8        1
# 102           3.0            5.9        2
# 116           3.0            5.5        2
# 109           3.6            6.1        2
# 104           3.0            5.8        2

# %%
print("predictior 1", dt_bag1.predict(np.array([3.2, 4.8]).reshape(1,2)))
print("predictior 2", dt_bag2.predict(np.array([3.2, 4.8]).reshape(1,2)))
print("predictior 3", dt_bag3.predict(np.array([3.2, 4.8]).reshape(1,2)))
# Out:
# predictior 1 [2]
# predictior 2 [1]
# predictior 3 [1]
